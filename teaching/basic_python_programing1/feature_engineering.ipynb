# %% [markdown]
# # Feature Engineering

# %%
import pandas as pd

# %%
df = pd.read_csv('data/us_indicators.csv')

# %%
# Change date type to datetime format.
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')

# %%
df
# Out:
#           date   cpi  policy_rate    neer  money_supply inflation_target  \
# 0   2001-01-31  1.32          1.5   89.24        147.07          inrange
# 1   2001-02-28  1.44          1.5   90.47        145.49          inrange
# 2   2001-03-31  1.44          1.5   89.33        140.02          inrange
# 3   2001-04-30  2.52          1.5   87.32        138.88          inrange
# 4   2001-05-31  2.76          1.5   87.16        139.49          inrange
# ..         ...   ...          ...     ...           ...              ...
# 277 2024-02-29 -0.77          2.5  118.51        718.27        outrrange
# 278 2024-03-31 -0.47          2.5  118.11        711.58        outrrange
# 279 2024-04-30  0.19          2.5  116.80        695.69        outrrange
# 280 2024-05-31  1.54          2.5  117.21        702.68          inrange
# 281 2024-06-30  1.54          2.5  117.55        702.68          inrange
#
#     type_of_monetary_policy
# 0                      ease
# 1                      ease
# 2                      ease
# 3                      ease
# 4                      ease
# ..                      ...
# 277                   tight
# 278                   tight
# 279                   tight
# 280                   tight
# 281                   tight
#
# [282 rows x 7 columns]

# %% [markdown]
# ## Feature Creation

# %% [markdown]
# ### Interaction

# %%
df['cpi_policy_rate'] = df['cpi'] * df['policy_rate']

# %%
df
# Out:
#           date   cpi  policy_rate    neer  money_supply inflation_target  \
# 0   2001-01-31  1.32          1.5   89.24        147.07          inrange
# 1   2001-02-28  1.44          1.5   90.47        145.49          inrange
# 2   2001-03-31  1.44          1.5   89.33        140.02          inrange
# 3   2001-04-30  2.52          1.5   87.32        138.88          inrange
# 4   2001-05-31  2.76          1.5   87.16        139.49          inrange
# ..         ...   ...          ...     ...           ...              ...
# 277 2024-02-29 -0.77          2.5  118.51        718.27        outrrange
# 278 2024-03-31 -0.47          2.5  118.11        711.58        outrrange
# 279 2024-04-30  0.19          2.5  116.80        695.69        outrrange
# 280 2024-05-31  1.54          2.5  117.21        702.68          inrange
# 281 2024-06-30  1.54          2.5  117.55        702.68          inrange
#
#     type_of_monetary_policy  cpi_policy_rate
# 0                      ease            1.980
# 1                      ease            2.160
# 2                      ease            2.160
# 3                      ease            3.780
# 4                      ease            4.140
# ..                      ...              ...
# 277                   tight           -1.925
# 278                   tight           -1.175
# 279                   tight            0.475
# 280                   tight            3.850
# 281                   tight            3.850
#
# [282 rows x 8 columns]

# %% [markdown]
# ### Extraction

# %%
df['month'] = df['date'].dt.month

# %%
df
# Out:
#           date   cpi  policy_rate    neer  money_supply inflation_target  \
# 0   2001-01-31  1.32          1.5   89.24        147.07          inrange
# 1   2001-02-28  1.44          1.5   90.47        145.49          inrange
# 2   2001-03-31  1.44          1.5   89.33        140.02          inrange
# 3   2001-04-30  2.52          1.5   87.32        138.88          inrange
# 4   2001-05-31  2.76          1.5   87.16        139.49          inrange
# ..         ...   ...          ...     ...           ...              ...
# 277 2024-02-29 -0.77          2.5  118.51        718.27        outrrange
# 278 2024-03-31 -0.47          2.5  118.11        711.58        outrrange
# 279 2024-04-30  0.19          2.5  116.80        695.69        outrrange
# 280 2024-05-31  1.54          2.5  117.21        702.68          inrange
# 281 2024-06-30  1.54          2.5  117.55        702.68          inrange
#
#     type_of_monetary_policy  cpi_policy_rate  month
# 0                      ease            1.980      1
# 1                      ease            2.160      2
# 2                      ease            2.160      3
# 3                      ease            3.780      4
# 4                      ease            4.140      5
# ..                      ...              ...    ...
# 277                   tight           -1.925      2
# 278                   tight           -1.175      3
# 279                   tight            0.475      4
# 280                   tight            3.850      5
# 281                   tight            3.850      6
#
# [282 rows x 9 columns]

# %% [markdown]
# ### Lag

# %%
df['money_supply_lag'] = df['money_supply'].shift(1)

# %%
df
# Out:
#           date   cpi  policy_rate    neer  money_supply inflation_target  \
# 0   2001-01-31  1.32          1.5   89.24        147.07          inrange
# 1   2001-02-28  1.44          1.5   90.47        145.49          inrange
# 2   2001-03-31  1.44          1.5   89.33        140.02          inrange
# 3   2001-04-30  2.52          1.5   87.32        138.88          inrange
# 4   2001-05-31  2.76          1.5   87.16        139.49          inrange
# ..         ...   ...          ...     ...           ...              ...
# 277 2024-02-29 -0.77          2.5  118.51        718.27        outrrange
# 278 2024-03-31 -0.47          2.5  118.11        711.58        outrrange
# 279 2024-04-30  0.19          2.5  116.80        695.69        outrrange
# 280 2024-05-31  1.54          2.5  117.21        702.68          inrange
# 281 2024-06-30  1.54          2.5  117.55        702.68          inrange
#
#     type_of_monetary_policy  cpi_policy_rate  month  money_supply_lag
# 0                      ease            1.980      1               NaN
# 1                      ease            2.160      2            147.07
# 2                      ease            2.160      3            145.49
# 3                      ease            3.780      4            140.02
# 4                      ease            4.140      5            138.88
# ..                      ...              ...    ...               ...
# 277                   tight           -1.925      2            721.62
# 278                   tight           -1.175      3            718.27
# 279                   tight            0.475      4            711.58
# 280                   tight            3.850      5            695.69
# 281                   tight            3.850      6            702.68
#
# [282 rows x 10 columns]

# %% [markdown]
# ### Change

# %%
df['cpi_change'] = df['cpi'].diff(1)

# %%
df
# Out:
#           date   cpi  policy_rate    neer  money_supply inflation_target  \
# 0   2001-01-31  1.32          1.5   89.24        147.07          inrange
# 1   2001-02-28  1.44          1.5   90.47        145.49          inrange
# 2   2001-03-31  1.44          1.5   89.33        140.02          inrange
# 3   2001-04-30  2.52          1.5   87.32        138.88          inrange
# 4   2001-05-31  2.76          1.5   87.16        139.49          inrange
# ..         ...   ...          ...     ...           ...              ...
# 277 2024-02-29 -0.77          2.5  118.51        718.27        outrrange
# 278 2024-03-31 -0.47          2.5  118.11        711.58        outrrange
# 279 2024-04-30  0.19          2.5  116.80        695.69        outrrange
# 280 2024-05-31  1.54          2.5  117.21        702.68          inrange
# 281 2024-06-30  1.54          2.5  117.55        702.68          inrange
#
#     type_of_monetary_policy  cpi_policy_rate  month  money_supply_lag  \
# 0                      ease            1.980      1               NaN
# 1                      ease            2.160      2            147.07
# 2                      ease            2.160      3            145.49
# 3                      ease            3.780      4            140.02
# 4                      ease            4.140      5            138.88
# ..                      ...              ...    ...               ...
# 277                   tight           -1.925      2            721.62
# 278                   tight           -1.175      3            718.27
# 279                   tight            0.475      4            711.58
# 280                   tight            3.850      5            695.69
# 281                   tight            3.850      6            702.68
#
#      cpi_change
# 0           NaN
# 1          0.12
# 2          0.00
# 3          1.08
# 4          0.24
# ..          ...
# 277        0.34
# 278        0.30
# 279        0.66
# 280        1.35
# 281        0.00
#
# [282 rows x 11 columns]

# %%
df['cpi_change_rate'] = df['cpi'].pct_change(1)

# %%
df
# Out:
#           date   cpi  policy_rate    neer  money_supply inflation_target  \
# 0   2001-01-31  1.32          1.5   89.24        147.07          inrange
# 1   2001-02-28  1.44          1.5   90.47        145.49          inrange
# 2   2001-03-31  1.44          1.5   89.33        140.02          inrange
# 3   2001-04-30  2.52          1.5   87.32        138.88          inrange
# 4   2001-05-31  2.76          1.5   87.16        139.49          inrange
# ..         ...   ...          ...     ...           ...              ...
# 277 2024-02-29 -0.77          2.5  118.51        718.27        outrrange
# 278 2024-03-31 -0.47          2.5  118.11        711.58        outrrange
# 279 2024-04-30  0.19          2.5  116.80        695.69        outrrange
# 280 2024-05-31  1.54          2.5  117.21        702.68          inrange
# 281 2024-06-30  1.54          2.5  117.55        702.68          inrange
#
#     type_of_monetary_policy  cpi_policy_rate  month  money_supply_lag  \
# 0                      ease            1.980      1               NaN
# 1                      ease            2.160      2            147.07
# 2                      ease            2.160      3            145.49
# 3                      ease            3.780      4            140.02
# 4                      ease            4.140      5            138.88
# ..                      ...              ...    ...               ...
# 277                   tight           -1.925      2            721.62
# 278                   tight           -1.175      3            718.27
# 279                   tight            0.475      4            711.58
# 280                   tight            3.850      5            695.69
# 281                   tight            3.850      6            702.68
#
#      cpi_change  cpi_change_rate
# 0           NaN              NaN
# 1          0.12         0.090909
# 2          0.00         0.000000
# 3          1.08         0.750000
# 4          0.24         0.095238
# ..          ...              ...
# 277        0.34        -0.306306
# 278        0.30        -0.389610
# 279        0.66        -1.404255
# 280        1.35         7.105263
# 281        0.00         0.000000
#
# [282 rows x 12 columns]

# %% [markdown]
# ### Rolling

# %%
df['cpi_rolling_mean'] = df['cpi'].rolling(window=10).mean()
df['cpi_rolling_std'] = df['cpi'].rolling(window=10).std()

# %%
df.head(20)
# Out:
#          date   cpi  policy_rate   neer  money_supply inflation_target  \
# 0  2001-01-31  1.32         1.50  89.24        147.07          inrange
# 1  2001-02-28  1.44         1.50  90.47        145.49          inrange
# 2  2001-03-31  1.44         1.50  89.33        140.02          inrange
# 3  2001-04-30  2.52         1.50  87.32        138.88          inrange
# 4  2001-05-31  2.76         1.50  87.16        139.49          inrange
# 5  2001-06-30  2.15         2.50  88.30        139.53          inrange
# 6  2001-07-31  2.03         2.50  87.81        138.87          inrange
# 7  2001-08-31  1.43         2.50  87.32        144.93          inrange
# 8  2001-09-30  1.30         2.50  88.12        144.44          inrange
# 9  2001-10-31  1.32         2.50  88.26        144.56          inrange
# 10 2001-11-30  0.96         2.50  89.42        148.71        outrrange
# 11 2001-12-31  0.72         2.25  91.11        148.43        outrrange
# 12 2002-01-31  0.84         2.00  91.88        147.27        outrrange
# 13 2002-02-28  0.36         2.00  92.56        149.90        outrrange
# 14 2002-03-31  0.60         2.00  92.89        150.91        outrrange
# 15 2002-04-30  0.47         2.00  92.36        152.66        outrrange
# 16 2002-05-31  0.24         2.00  92.02        155.95        outrrange
# 17 2002-06-30  0.36         2.00  92.03        158.75        outrrange
# 18 2002-07-31  0.24         2.00  92.41        157.59        outrrange
# 19 2002-08-31  0.36         2.00  91.03        159.25        outrrange
#
#    type_of_monetary_policy  cpi_policy_rate  month  money_supply_lag  \
# 0                     ease            1.980      1               NaN
# 1                     ease            2.160      2            147.07
# 2                     ease            2.160      3            145.49
# 3                     ease            3.780      4            140.02
# 4                     ease            4.140      5            138.88
# 5                    tight            5.375      6            139.49
# 6                    tight            5.075      7            139.53
# 7                    tight            3.575      8            138.87
# 8                    tight            3.250      9            144.93
# 9                    tight            3.300     10            144.44
# 10                   tight            2.400     11            144.56
# 11                   tight            1.620     12            148.71
# 12                   tight            1.680      1            148.43
# 13                   tight            0.720      2            147.27
# 14                   tight            1.200      3            149.90
# 15                   tight            0.940      4            150.91
# 16                   tight            0.480      5            152.66
# 17                   tight            0.720      6            155.95
# 18                   tight            0.480      7            158.75
# 19                   tight            0.720      8            157.59
#
#     cpi_change  cpi_change_rate  cpi_rolling_mean  cpi_rolling_std
# 0          NaN              NaN               NaN              NaN
# 1         0.12         0.090909               NaN              NaN
# 2         0.00         0.000000               NaN              NaN
# 3         1.08         0.750000               NaN              NaN
# 4         0.24         0.095238               NaN              NaN
# 5        -0.61        -0.221014               NaN              NaN
# 6        -0.12        -0.055814               NaN              NaN
# 7        -0.60        -0.295567               NaN              NaN
# 8        -0.13        -0.090909               NaN              NaN
# 9         0.02         0.015385             1.771         0.549130
# 10       -0.36        -0.272727             1.735         0.592101
# 11       -0.24        -0.250000             1.663         0.670540
# 12        0.12         0.166667             1.603         0.717883
# 13       -0.48        -0.571429             1.387         0.736041
# 14        0.24         0.666667             1.171         0.590996
# 15       -0.13        -0.216667             1.003         0.515774
# 16       -0.23        -0.489362             0.824         0.421800
# 17        0.12         0.500000             0.717         0.385113
# 18       -0.12        -0.333333             0.611         0.351203
# 19        0.12         0.500000             0.515         0.253476

# %% [markdown]
# ## Encoding

# %% [markdown]
# ### Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder_inflation = LabelEncoder()
df['inflation_target'] = label_encoder_inflation.fit_transform(df['inflation_target'])

# %%
label_encoder_policy = LabelEncoder()
df['type_of_monetary_policy'] = label_encoder_policy.fit_transform(df['type_of_monetary_policy'])

# %%
df
# Out:
#           date   cpi  policy_rate    neer  money_supply  inflation_target  \
# 0   2001-01-31  1.32          1.5   89.24        147.07                 0
# 1   2001-02-28  1.44          1.5   90.47        145.49                 0
# 2   2001-03-31  1.44          1.5   89.33        140.02                 0
# 3   2001-04-30  2.52          1.5   87.32        138.88                 0
# 4   2001-05-31  2.76          1.5   87.16        139.49                 0
# ..         ...   ...          ...     ...           ...               ...
# 277 2024-02-29 -0.77          2.5  118.51        718.27                 1
# 278 2024-03-31 -0.47          2.5  118.11        711.58                 1
# 279 2024-04-30  0.19          2.5  116.80        695.69                 1
# 280 2024-05-31  1.54          2.5  117.21        702.68                 0
# 281 2024-06-30  1.54          2.5  117.55        702.68                 0
#
#      type_of_monetary_policy  cpi_policy_rate  month  money_supply_lag  \
# 0                          0            1.980      1               NaN
# 1                          0            2.160      2            147.07
# 2                          0            2.160      3            145.49
# 3                          0            3.780      4            140.02
# 4                          0            4.140      5            138.88
# ..                       ...              ...    ...               ...
# 277                        1           -1.925      2            721.62
# 278                        1           -1.175      3            718.27
# 279                        1            0.475      4            711.58
# 280                        1            3.850      5            695.69
# 281                        1            3.850      6            702.68
#
#      cpi_change  cpi_change_rate  cpi_rolling_mean  cpi_rolling_std
# 0           NaN              NaN               NaN              NaN
# 1          0.12         0.090909               NaN              NaN
# 2          0.00         0.000000               NaN              NaN
# 3          1.08         0.750000               NaN              NaN
# 4          0.24         0.095238               NaN              NaN
# ..          ...              ...               ...              ...
# 277        0.34        -0.306306            -0.114         0.668019
# 278        0.30        -0.389610            -0.214         0.634931
# 279        0.66        -1.404255            -0.218         0.631942
# 280        1.35         7.105263            -0.102         0.829495
# 281        0.00         0.000000            -0.036         0.935761
#
# [282 rows x 14 columns]

# %% [markdown]
# ### One-hot Encoding

# %%
df = pd.get_dummies(df, columns=['month'], prefix=['m'])

# %%
df
# Out:
#           date   cpi  policy_rate    neer  money_supply  inflation_target  \
# 0   2001-01-31  1.32          1.5   89.24        147.07                 0
# 1   2001-02-28  1.44          1.5   90.47        145.49                 0
# 2   2001-03-31  1.44          1.5   89.33        140.02                 0
# 3   2001-04-30  2.52          1.5   87.32        138.88                 0
# 4   2001-05-31  2.76          1.5   87.16        139.49                 0
# ..         ...   ...          ...     ...           ...               ...
# 277 2024-02-29 -0.77          2.5  118.51        718.27                 1
# 278 2024-03-31 -0.47          2.5  118.11        711.58                 1
# 279 2024-04-30  0.19          2.5  116.80        695.69                 1
# 280 2024-05-31  1.54          2.5  117.21        702.68                 0
# 281 2024-06-30  1.54          2.5  117.55        702.68                 0
#
#      type_of_monetary_policy  cpi_policy_rate  money_supply_lag  cpi_change  \
# 0                          0            1.980               NaN         NaN
# 1                          0            2.160            147.07        0.12
# 2                          0            2.160            145.49        0.00
# 3                          0            3.780            140.02        1.08
# 4                          0            4.140            138.88        0.24
# ..                       ...              ...               ...         ...
# 277                        1           -1.925            721.62        0.34
# 278                        1           -1.175            718.27        0.30
# 279                        1            0.475            711.58        0.66
# 280                        1            3.850            695.69        1.35
# 281                        1            3.850            702.68        0.00
#
#      ...    m_3    m_4    m_5    m_6    m_7    m_8    m_9   m_10   m_11   m_12
# 0    ...  False  False  False  False  False  False  False  False  False  False
# 1    ...  False  False  False  False  False  False  False  False  False  False
# 2    ...   True  False  False  False  False  False  False  False  False  False
# 3    ...  False   True  False  False  False  False  False  False  False  False
# 4    ...  False  False   True  False  False  False  False  False  False  False
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 277  ...  False  False  False  False  False  False  False  False  False  False
# 278  ...   True  False  False  False  False  False  False  False  False  False
# 279  ...  False   True  False  False  False  False  False  False  False  False
# 280  ...  False  False   True  False  False  False  False  False  False  False
# 281  ...  False  False  False   True  False  False  False  False  False  False
#
# [282 rows x 25 columns]

# %%
df[['date'] + [x for x in df.columns if 'm_' in x]]
# Out:
#           date    m_1    m_2    m_3    m_4    m_5    m_6    m_7    m_8    m_9  \
# 0   2001-01-31   True  False  False  False  False  False  False  False  False
# 1   2001-02-28  False   True  False  False  False  False  False  False  False
# 2   2001-03-31  False  False   True  False  False  False  False  False  False
# 3   2001-04-30  False  False  False   True  False  False  False  False  False
# 4   2001-05-31  False  False  False  False   True  False  False  False  False
# ..         ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 277 2024-02-29  False   True  False  False  False  False  False  False  False
# 278 2024-03-31  False  False   True  False  False  False  False  False  False
# 279 2024-04-30  False  False  False   True  False  False  False  False  False
# 280 2024-05-31  False  False  False  False   True  False  False  False  False
# 281 2024-06-30  False  False  False  False  False   True  False  False  False
#
#       m_10   m_11   m_12
# 0    False  False  False
# 1    False  False  False
# 2    False  False  False
# 3    False  False  False
# 4    False  False  False
# ..     ...    ...    ...
# 277  False  False  False
# 278  False  False  False
# 279  False  False  False
# 280  False  False  False
# 281  False  False  False
#
# [282 rows x 13 columns]

# %% [markdown]
# ## Transformation

# %% [markdown]
# ### Normalization

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df['neer'].describe()
# Out:
# count    282.000000
# mean     103.934220
# std       11.502054
# min       85.840000
# 25%       94.317500
# 50%      102.730000
# 75%      114.322500
# max      126.920000
# Name: neer, dtype: float64

# %%
neer_scaler = MinMaxScaler()
df['neer'] = neer_scaler.fit_transform(df[['neer']])

# %%
df
# Out:
#           date   cpi  policy_rate      neer  money_supply  inflation_target  \
# 0   2001-01-31  1.32          1.5  0.082765        147.07                 0
# 1   2001-02-28  1.44          1.5  0.112707        145.49                 0
# 2   2001-03-31  1.44          1.5  0.084956        140.02                 0
# 3   2001-04-30  2.52          1.5  0.036027        138.88                 0
# 4   2001-05-31  2.76          1.5  0.032132        139.49                 0
# ..         ...   ...          ...       ...           ...               ...
# 277 2024-02-29 -0.77          2.5  0.795278        718.27                 1
# 278 2024-03-31 -0.47          2.5  0.785540        711.58                 1
# 279 2024-04-30  0.19          2.5  0.753651        695.69                 1
# 280 2024-05-31  1.54          2.5  0.763632        702.68                 0
# 281 2024-06-30  1.54          2.5  0.771908        702.68                 0
#
#      type_of_monetary_policy  cpi_policy_rate  money_supply_lag  cpi_change  \
# 0                          0            1.980               NaN         NaN
# 1                          0            2.160            147.07        0.12
# 2                          0            2.160            145.49        0.00
# 3                          0            3.780            140.02        1.08
# 4                          0            4.140            138.88        0.24
# ..                       ...              ...               ...         ...
# 277                        1           -1.925            721.62        0.34
# 278                        1           -1.175            718.27        0.30
# 279                        1            0.475            711.58        0.66
# 280                        1            3.850            695.69        1.35
# 281                        1            3.850            702.68        0.00
#
#      ...    m_3    m_4    m_5    m_6    m_7    m_8    m_9   m_10   m_11   m_12
# 0    ...  False  False  False  False  False  False  False  False  False  False
# 1    ...  False  False  False  False  False  False  False  False  False  False
# 2    ...   True  False  False  False  False  False  False  False  False  False
# 3    ...  False   True  False  False  False  False  False  False  False  False
# 4    ...  False  False   True  False  False  False  False  False  False  False
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 277  ...  False  False  False  False  False  False  False  False  False  False
# 278  ...   True  False  False  False  False  False  False  False  False  False
# 279  ...  False   True  False  False  False  False  False  False  False  False
# 280  ...  False  False   True  False  False  False  False  False  False  False
# 281  ...  False  False  False   True  False  False  False  False  False  False
#
# [282 rows x 25 columns]

# %%
df['neer'].describe()
# Out:
# count    282.000000
# mean       0.440463
# std        0.279992
# min        0.000000
# 25%        0.206366
# 50%        0.411149
# 75%        0.693342
# max        1.000000
# Name: neer, dtype: float64

# %% [markdown]
# ### Standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
df['money_supply'].describe()
# Out:
# count    282.000000
# mean     432.494929
# std      202.217172
# min      138.870000
# 25%      237.987500
# 50%      470.675000
# 75%      613.550000
# max      765.730000
# Name: money_supply, dtype: float64

# %%
money_supply_scaler = StandardScaler()
df['money_supply'] = money_supply_scaler.fit_transform(df[['money_supply']])

# %%
df
# Out:
#           date   cpi  policy_rate      neer  money_supply  inflation_target  \
# 0   2001-01-31  1.32          1.5  0.082765     -1.413986                 0
# 1   2001-02-28  1.44          1.5  0.112707     -1.421814                 0
# 2   2001-03-31  1.44          1.5  0.084956     -1.448912                 0
# 3   2001-04-30  2.52          1.5  0.036027     -1.454560                 0
# 4   2001-05-31  2.76          1.5  0.032132     -1.451538                 0
# ..         ...   ...          ...       ...           ...               ...
# 277 2024-02-29 -0.77          2.5  0.795278      1.415721                 1
# 278 2024-03-31 -0.47          2.5  0.785540      1.382579                 1
# 279 2024-04-30  0.19          2.5  0.753651      1.303860                 1
# 280 2024-05-31  1.54          2.5  0.763632      1.338489                 0
# 281 2024-06-30  1.54          2.5  0.771908      1.338489                 0
#
#      type_of_monetary_policy  cpi_policy_rate  money_supply_lag  cpi_change  \
# 0                          0            1.980               NaN         NaN
# 1                          0            2.160            147.07        0.12
# 2                          0            2.160            145.49        0.00
# 3                          0            3.780            140.02        1.08
# 4                          0            4.140            138.88        0.24
# ..                       ...              ...               ...         ...
# 277                        1           -1.925            721.62        0.34
# 278                        1           -1.175            718.27        0.30
# 279                        1            0.475            711.58        0.66
# 280                        1            3.850            695.69        1.35
# 281                        1            3.850            702.68        0.00
#
#      ...    m_3    m_4    m_5    m_6    m_7    m_8    m_9   m_10   m_11   m_12
# 0    ...  False  False  False  False  False  False  False  False  False  False
# 1    ...  False  False  False  False  False  False  False  False  False  False
# 2    ...   True  False  False  False  False  False  False  False  False  False
# 3    ...  False   True  False  False  False  False  False  False  False  False
# 4    ...  False  False   True  False  False  False  False  False  False  False
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 277  ...  False  False  False  False  False  False  False  False  False  False
# 278  ...   True  False  False  False  False  False  False  False  False  False
# 279  ...  False   True  False  False  False  False  False  False  False  False
# 280  ...  False  False   True  False  False  False  False  False  False  False
# 281  ...  False  False  False   True  False  False  False  False  False  False
#
# [282 rows x 25 columns]

# %%
df['money_supply'].describe()
# Out:
# count    2.820000e+02
# mean    -1.007862e-16
# std      1.001778e+00
# min     -1.454609e+00
# 25%     -9.635839e-01
# 50%      1.891429e-01
# 75%      8.969414e-01
# max      1.650837e+00
# Name: money_supply, dtype: float64

# %% [markdown]
# ## Dimensionality Reduction

# %%
from sklearn.decomposition import PCA

# %%
# Drop date as PCA only accept number.
# Drop ['money_supply_lag', 'cpi_change', 'cpi_change_rate', 'cpi_rolling_mean', 'cpi_rolling_std'] as PCA not accept NaN.
features = df.drop(columns=['date', 'money_supply_lag', 'cpi_change', 'cpi_change_rate', 'cpi_rolling_mean', 'cpi_rolling_std'])

# %%
features
# Out:
#       cpi  policy_rate      neer  money_supply  inflation_target  \
# 0    1.32          1.5  0.082765     -1.413986                 0
# 1    1.44          1.5  0.112707     -1.421814                 0
# 2    1.44          1.5  0.084956     -1.448912                 0
# 3    2.52          1.5  0.036027     -1.454560                 0
# 4    2.76          1.5  0.032132     -1.451538                 0
# ..    ...          ...       ...           ...               ...
# 277 -0.77          2.5  0.795278      1.415721                 1
# 278 -0.47          2.5  0.785540      1.382579                 1
# 279  0.19          2.5  0.753651      1.303860                 1
# 280  1.54          2.5  0.763632      1.338489                 0
# 281  1.54          2.5  0.771908      1.338489                 0
#
#      type_of_monetary_policy  cpi_policy_rate    m_1    m_2    m_3    m_4  \
# 0                          0            1.980   True  False  False  False
# 1                          0            2.160  False   True  False  False
# 2                          0            2.160  False  False   True  False
# 3                          0            3.780  False  False  False   True
# 4                          0            4.140  False  False  False  False
# ..                       ...              ...    ...    ...    ...    ...
# 277                        1           -1.925  False   True  False  False
# 278                        1           -1.175  False  False   True  False
# 279                        1            0.475  False  False  False   True
# 280                        1            3.850  False  False  False  False
# 281                        1            3.850  False  False  False  False
#
#        m_5    m_6    m_7    m_8    m_9   m_10   m_11   m_12
# 0    False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False
# 4     True  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...
# 277  False  False  False  False  False  False  False  False
# 278  False  False  False  False  False  False  False  False
# 279  False  False  False  False  False  False  False  False
# 280   True  False  False  False  False  False  False  False
# 281  False   True  False  False  False  False  False  False
#
# [282 rows x 19 columns]

# %%
pca = PCA(n_components=2)
pca_data = pca.fit_transform(features)

# %%
pca_data
# Out:
# array([[-3.03893716e+00, -1.30593762e-01],
#        [-2.83608544e+00, -5.50576112e-02],
#        [-2.83395669e+00, -6.28266350e-02],
#        [-1.00383584e+00,  6.00403020e-01],
#        [-5.97294441e-01,  7.48839824e-01],
#        [ 5.78805442e-01, -4.90444042e-01],
#        [ 2.61395477e-01, -5.45898286e-01],
#        [-1.33042873e+00, -8.04692301e-01],
#        [-1.67515074e+00, -8.64017937e-01],
#        [-1.62225918e+00, -8.54426701e-01],
#        [-2.57284053e+00, -1.01868077e+00],
#        [-3.41026659e+00, -1.00176408e+00],
#        [-3.35062997e+00, -8.16384618e-01],
#        [-4.39425733e+00, -1.06464959e+00],
#        [-3.87335472e+00, -9.36815696e-01],
#        [-4.15550872e+00, -1.00329545e+00],
#        [-4.65544883e+00, -1.12168344e+00],
#        [-4.39525995e+00, -1.05730560e+00],
#        [-4.65547216e+00, -1.12289153e+00],
#        [-4.39506763e+00, -1.05906659e+00],
#        [-4.15310545e+00, -1.01477929e+00],
#        [-1.85657205e+00, -4.40179896e-01],
#        [-2.73403765e+00, -2.85727878e-01],
#        [-2.03901150e+00, -7.77075313e-02],
#        [-9.19288664e-01,  2.58093612e-01],
#        [-1.38333123e+00,  1.22986963e-01],
#        [-1.86644798e+00, -2.02159957e-02],
#        [-2.31028711e+00, -1.51533663e-01],
#        [-1.63504395e+00,  5.46192159e-02],
#        [-2.92053495e+00,  2.43678533e-01],
#        [-2.74626818e+00,  3.23085381e-01],
#        [-2.06468831e+00,  6.38495641e-01],
#        [-2.76471758e+00,  3.26959522e-01],
#        [-3.46292100e+00,  1.20132626e-02],
#        [-2.59174814e+00,  4.13570130e-01],
#        [-2.76654311e+00,  3.35326758e-01],
#        [-3.46598236e+00,  2.39590881e-02],
#        [-2.11431017e+00,  6.40618286e-01],
#        [-1.76553433e+00,  7.99527285e-01],
#        [-1.63402719e+00,  8.58803843e-01],
#        [-1.82157662e+00,  7.69191533e-01],
#        [-7.81949472e-01,  1.21693364e+00],
#        [-6.07183072e-01,  1.29493150e+00],
#        [-4.27073241e-02,  9.75098044e-01],
#        [ 7.35692112e-01,  1.25807411e+00],
#        [ 1.38098701e+00,  9.46737942e-01],
#        [ 4.83542978e-01,  7.09486939e-01],
#        [ 1.25892737e+00,  3.68042075e-01],
#        [ 7.78933321e-01,  2.58704195e-01],
#        [ 1.91191892e-01,  1.22050224e-01],
#        [ 2.45973400e+00,  2.32525960e-01],
#        [ 3.25669602e+00,  3.90575023e-01],
#        [ 4.05424213e+00,  5.44417301e-01],
#        [ 4.91918226e+00,  2.65627513e-01],
#        [ 1.03621621e+01,  6.28476599e-01],
#        [-6.42681038e+00, -8.15329060e-01],
#        [-5.61908310e+00,  2.68728671e-02],
#        [-3.05029769e+00,  2.79321551e+00],
#        [-3.76960048e+00,  2.03976280e+00],
#        [-4.63804261e+00,  1.06782752e+00],
#        [-5.21601008e+00,  4.01364022e-01],
#        [-5.56664516e+00,  4.76114736e-02],
#        [-4.31344673e+00,  1.37497261e+00],
#        [-3.80154395e+00,  1.94301696e+00],
#        [-3.55842568e+00,  2.20294797e+00],
#        [-3.96069135e+00,  1.79438144e+00],
#        [-3.17554612e+00,  2.62100509e+00],
#        [-1.67257429e+00,  4.26691929e+00],
#        [-1.33982052e+00,  4.61727240e+00],
#        [-2.12859195e+00,  3.74107579e+00],
#        [-3.24867985e-01,  5.67993441e+00],
#        [ 9.47256218e-02,  6.09384345e+00],
#        [ 6.51146777e-02,  6.02696578e+00],
#        [ 2.15751902e+00,  5.79068673e+00],
#        [ 2.31171992e+00,  4.30865099e+00],
#        [ 1.78980072e+00,  4.00539202e+00],
#        [ 1.24980312e+00,  3.77177584e+00],
#        [ 3.09521709e+00,  3.68127950e+00],
#        [ 3.04716544e+00,  2.84459828e+00],
#        [ 9.78160461e-01,  2.03522394e+00],
#        [ 4.59900995e-02,  1.27013108e+00],
#        [-2.62536565e-01,  1.17832451e+00],
#        [-4.19472699e+00, -3.16514134e-01],
#        [-4.84127903e+00, -4.94585781e-01],
#        [-4.52213819e+00, -3.90060874e-01],
#        [-3.19247003e+00, -2.75157552e-01],
#        [-4.48250633e+00, -6.93266731e-01],
#        [-6.10194477e+00, -9.50053982e-01],
#        [-6.45378632e+00, -9.78985627e-01],
#        [-7.49389005e+00, -1.12613230e+00],
#        [-8.23061821e+00, -1.27100997e+00],
#        [-7.32840776e+00, -1.12382390e+00],
#        [-6.53122227e+00, -9.99705437e-01],
#        [-4.77679348e+00, -7.26223732e-01],
#        [-1.20655005e+00, -1.08410715e-01],
#        [-1.20631057e+00, -1.10238764e-01]])

# %%
pca_df = pd.DataFrame(data=pca_data)

# %%
pca_df
# Out:
#             0         1
# 0   -3.038937 -0.130594
# 1   -2.836085 -0.055058
# 2   -2.833957 -0.062827
# 3   -1.003836  0.600403
# 4   -0.597294  0.748840
# ..        ...       ...
# 277 -7.328408 -1.123824
# 278 -6.531222 -0.999705
# 279 -4.776793 -0.726224
# 280 -1.206550 -0.108411
# 281 -1.206311 -0.110239
#
# [282 rows x 2 columns]

# %%
features_df = pd.concat([df[['date']], pca_df], axis=1)
features_df
# Out:
#           date         0         1
# 0   2001-01-31 -3.038937 -0.130594
# 1   2001-02-28 -2.836085 -0.055058
# 2   2001-03-31 -2.833957 -0.062827
# 3   2001-04-30 -1.003836  0.600403
# 4   2001-05-31 -0.597294  0.748840
# ..         ...       ...       ...
# 277 2024-02-29 -7.328408 -1.123824
# 278 2024-03-31 -6.531222 -0.999705
# 279 2024-04-30 -4.776793 -0.726224
# 280 2024-05-31 -1.206550 -0.108411
# 281 2024-06-30 -1.206311 -0.110239
#
# [282 rows x 3 columns]
