# %% [markdown]
# # Data Cleansing

# %%
import pandas as pd

# %%
df = pd.read_csv('data/us_indicators_raw.csv')

# %%
df
# Out:
#           date   cpi  policy_rate    neer  money_supply inflation_target  \
# 0    31/1/2001  1.32          1.5   89.24        147.07          inrange
# 1    28/2/2001  1.44          1.5   90.47        145.49          inrange
# 2    31/3/2001  1.44         -0.5   89.33        140.02          inrange
# 3    30/4/2001  2.52         -1.0   87.32        138.88          inrange
# 4    31/5/2001  2.76          1.5   87.16        139.49          inrange
# ..         ...   ...          ...     ...           ...              ...
# 278  29/2/2024 -0.77          2.5  118.51        718.27        outrrange
# 279  31/3/2024 -0.47          2.5  118.11        711.58        outrrange
# 280  30/4/2024  0.19          2.5  116.80        695.69        outrrange
# 281  31/5/2024  1.54          2.5  117.21        702.68          inrange
# 282  30/6/2024  1.54          2.5  117.55        702.68          inrange
#
#     type_of_monetary_policy
# 0                      ease
# 1                      ease
# 2                      ease
# 3                      ease
# 4                      ease
# ..                      ...
# 278                   tight
# 279                   tight
# 280                   tight
# 281                   tight
# 282                   tight
#
# [283 rows x 7 columns]

# %% [markdown]
# ## Data Type

# %%
modified_df = df.copy()

# %% [markdown]
# ### Number

# %%
modified_df['policy_rate'].dtype
# Out:
# dtype('float64')

# %%
modified_df['policy_rate'] = modified_df['policy_rate'].astype(int)

# %%
modified_df['policy_rate'].dtype
# Out:
# dtype('int64')

# %%
modified_df
# Out:
#           date   cpi  policy_rate    neer  money_supply inflation_target  \
# 0    31/1/2001  1.32            1   89.24        147.07          inrange
# 1    28/2/2001  1.44            1   90.47        145.49          inrange
# 2    31/3/2001  1.44            0   89.33        140.02          inrange
# 3    30/4/2001  2.52           -1   87.32        138.88          inrange
# 4    31/5/2001  2.76            1   87.16        139.49          inrange
# ..         ...   ...          ...     ...           ...              ...
# 278  29/2/2024 -0.77            2  118.51        718.27        outrrange
# 279  31/3/2024 -0.47            2  118.11        711.58        outrrange
# 280  30/4/2024  0.19            2  116.80        695.69        outrrange
# 281  31/5/2024  1.54            2  117.21        702.68          inrange
# 282  30/6/2024  1.54            2  117.55        702.68          inrange
#
#     type_of_monetary_policy
# 0                      ease
# 1                      ease
# 2                      ease
# 3                      ease
# 4                      ease
# ..                      ...
# 278                   tight
# 279                   tight
# 280                   tight
# 281                   tight
# 282                   tight
#
# [283 rows x 7 columns]

# %%
modified_df['policy_rate'] = modified_df['policy_rate'].astype(float)

# %%
modified_df['policy_rate'].dtype
# Out:
# dtype('float64')

# %%
modified_df
# Out:
#           date   cpi  policy_rate    neer  money_supply inflation_target  \
# 0    31/1/2001  1.32          1.0   89.24        147.07          inrange
# 1    28/2/2001  1.44          1.0   90.47        145.49          inrange
# 2    31/3/2001  1.44          0.0   89.33        140.02          inrange
# 3    30/4/2001  2.52         -1.0   87.32        138.88          inrange
# 4    31/5/2001  2.76          1.0   87.16        139.49          inrange
# ..         ...   ...          ...     ...           ...              ...
# 278  29/2/2024 -0.77          2.0  118.51        718.27        outrrange
# 279  31/3/2024 -0.47          2.0  118.11        711.58        outrrange
# 280  30/4/2024  0.19          2.0  116.80        695.69        outrrange
# 281  31/5/2024  1.54          2.0  117.21        702.68          inrange
# 282  30/6/2024  1.54          2.0  117.55        702.68          inrange
#
#     type_of_monetary_policy
# 0                      ease
# 1                      ease
# 2                      ease
# 3                      ease
# 4                      ease
# ..                      ...
# 278                   tight
# 279                   tight
# 280                   tight
# 281                   tight
# 282                   tight
#
# [283 rows x 7 columns]

# %% [markdown]
# ### Text

# %%
modified_df['money_supply'].dtype
# Out:
# dtype('float64')

# %%
modified_df['money_supply'] = modified_df['money_supply'] * 1000

# %%
modified_df
# Out:
#           date   cpi  policy_rate    neer  money_supply inflation_target  \
# 0    31/1/2001  1.32          1.0   89.24      147070.0          inrange
# 1    28/2/2001  1.44          1.0   90.47      145490.0          inrange
# 2    31/3/2001  1.44          0.0   89.33      140020.0          inrange
# 3    30/4/2001  2.52         -1.0   87.32      138880.0          inrange
# 4    31/5/2001  2.76          1.0   87.16      139490.0          inrange
# ..         ...   ...          ...     ...           ...              ...
# 278  29/2/2024 -0.77          2.0  118.51      718270.0        outrrange
# 279  31/3/2024 -0.47          2.0  118.11      711580.0        outrrange
# 280  30/4/2024  0.19          2.0  116.80      695690.0        outrrange
# 281  31/5/2024  1.54          2.0  117.21      702680.0          inrange
# 282  30/6/2024  1.54          2.0  117.55      702680.0          inrange
#
#     type_of_monetary_policy
# 0                      ease
# 1                      ease
# 2                      ease
# 3                      ease
# 4                      ease
# ..                      ...
# 278                   tight
# 279                   tight
# 280                   tight
# 281                   tight
# 282                   tight
#
# [283 rows x 7 columns]

# %%
modified_df['money_supply'] = modified_df['money_supply'].astype(str)

# %%
modified_df['money_supply'].dtype
# Out:
# dtype('O')

# %%
modified_df['money_supply'] = modified_df['money_supply'] + " MUSD"

# %%
modified_df
# Out:
#           date   cpi  policy_rate    neer   money_supply inflation_target  \
# 0    31/1/2001  1.32          1.0   89.24  147070.0 MUSD          inrange
# 1    28/2/2001  1.44          1.0   90.47  145490.0 MUSD          inrange
# 2    31/3/2001  1.44          0.0   89.33  140020.0 MUSD          inrange
# 3    30/4/2001  2.52         -1.0   87.32  138880.0 MUSD          inrange
# 4    31/5/2001  2.76          1.0   87.16  139490.0 MUSD          inrange
# ..         ...   ...          ...     ...            ...              ...
# 278  29/2/2024 -0.77          2.0  118.51  718270.0 MUSD        outrrange
# 279  31/3/2024 -0.47          2.0  118.11  711580.0 MUSD        outrrange
# 280  30/4/2024  0.19          2.0  116.80  695690.0 MUSD        outrrange
# 281  31/5/2024  1.54          2.0  117.21  702680.0 MUSD          inrange
# 282  30/6/2024  1.54          2.0  117.55  702680.0 MUSD          inrange
#
#     type_of_monetary_policy
# 0                      ease
# 1                      ease
# 2                      ease
# 3                      ease
# 4                      ease
# ..                      ...
# 278                   tight
# 279                   tight
# 280                   tight
# 281                   tight
# 282                   tight
#
# [283 rows x 7 columns]

# %% [markdown]
# ### Date Time

# %%
df['date'].dtype
# Out:
# dtype('O')

# %%
df.sort_values(by='date')
# Out:
#           date     cpi  policy_rate    neer  money_supply inflation_target  \
# 1    28/2/2001    1.44         1.50   90.47        145.49          inrange
# 14   28/2/2002    0.30         2.00   92.56        149.90        outrrange
# 13   28/2/2002    0.36         2.00   92.56        149.90        outrrange
# 26   28/2/2003  100.00         1.75   87.85        157.63          inrange
# 50   28/2/2005    2.48         2.00   90.58        198.82          inrange
# ..         ...     ...          ...     ...           ...              ...
# 224  31/8/2019    0.52         1.50  125.18        664.44        outrrange
# 236  31/8/2020   -0.50         0.50  122.21        724.00        outrrange
# 248  31/8/2021   -0.02         0.50  114.27        724.77        outrrange
# 260  31/8/2022    7.86         0.75  114.34        672.19        outrrange
# 272  31/8/2023    0.88         2.25  120.44        711.42        outrrange
#
#     type_of_monetary_policy
# 1                      ease
# 14                    tight
# 13                    tight
# 26                     ease
# 50                    tight
# ..                      ...
# 224                    ease
# 236                    ease
# 248                    ease
# 260                    ease
# 272                   tight
#
# [283 rows x 7 columns]

# %%
df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')

# %% [markdown]
# see date format at https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior

# %%
df['date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.sort_values(by='date')
# Out:
#           date   cpi  policy_rate    neer  money_supply inflation_target  \
# 0   2001-01-31  1.32          1.5   89.24        147.07          inrange
# 1   2001-02-28  1.44          1.5   90.47        145.49          inrange
# 2   2001-03-31  1.44         -0.5   89.33        140.02          inrange
# 3   2001-04-30  2.52         -1.0   87.32        138.88          inrange
# 4   2001-05-31  2.76          1.5   87.16        139.49          inrange
# ..         ...   ...          ...     ...           ...              ...
# 278 2024-02-29 -0.77          2.5  118.51        718.27        outrrange
# 279 2024-03-31 -0.47          2.5  118.11        711.58        outrrange
# 280 2024-04-30  0.19          2.5  116.80        695.69        outrrange
# 281 2024-05-31  1.54          2.5  117.21        702.68          inrange
# 282 2024-06-30  1.54          2.5  117.55        702.68          inrange
#
#     type_of_monetary_policy
# 0                      ease
# 1                      ease
# 2                      ease
# 3                      ease
# 4                      ease
# ..                      ...
# 278                   tight
# 279                   tight
# 280                   tight
# 281                   tight
# 282                   tight
#
# [283 rows x 7 columns]

# %% [markdown]
# ## Data Filtering

# %% [markdown]
# ### Filter Column

# %% [markdown]
# #### By Name

# %%
policy_cols = ['date', 'policy_rate', 'money_supply', 'type_of_monetary_policy']

# %%
df[policy_cols]
# Out:
#           date  policy_rate  money_supply type_of_monetary_policy
# 0   2001-01-31          1.5        147.07                    ease
# 1   2001-02-28          1.5        145.49                    ease
# 2   2001-03-31         -0.5        140.02                    ease
# 3   2001-04-30         -1.0        138.88                    ease
# 4   2001-05-31          1.5        139.49                    ease
# ..         ...          ...           ...                     ...
# 278 2024-02-29          2.5        718.27                   tight
# 279 2024-03-31          2.5        711.58                   tight
# 280 2024-04-30          2.5        695.69                   tight
# 281 2024-05-31          2.5        702.68                   tight
# 282 2024-06-30          2.5        702.68                   tight
#
# [283 rows x 4 columns]

# %%
df.drop(columns=['cpi', 'inflation_target'])
# Out:
#           date  policy_rate    neer  money_supply type_of_monetary_policy
# 0   2001-01-31          1.5   89.24        147.07                    ease
# 1   2001-02-28          1.5   90.47        145.49                    ease
# 2   2001-03-31         -0.5   89.33        140.02                    ease
# 3   2001-04-30         -1.0   87.32        138.88                    ease
# 4   2001-05-31          1.5   87.16        139.49                    ease
# ..         ...          ...     ...           ...                     ...
# 278 2024-02-29          2.5  118.51        718.27                   tight
# 279 2024-03-31          2.5  118.11        711.58                   tight
# 280 2024-04-30          2.5  116.80        695.69                   tight
# 281 2024-05-31          2.5  117.21        702.68                   tight
# 282 2024-06-30          2.5  117.55        702.68                   tight
#
# [283 rows x 5 columns]

# %%
df.loc[:, policy_cols]
# Out:
#           date  policy_rate  money_supply type_of_monetary_policy
# 0   2001-01-31          1.5        147.07                    ease
# 1   2001-02-28          1.5        145.49                    ease
# 2   2001-03-31         -0.5        140.02                    ease
# 3   2001-04-30         -1.0        138.88                    ease
# 4   2001-05-31          1.5        139.49                    ease
# ..         ...          ...           ...                     ...
# 278 2024-02-29          2.5        718.27                   tight
# 279 2024-03-31          2.5        711.58                   tight
# 280 2024-04-30          2.5        695.69                   tight
# 281 2024-05-31          2.5        702.68                   tight
# 282 2024-06-30          2.5        702.68                   tight
#
# [283 rows x 4 columns]

# %% [markdown]
# #### By Index

# %%
df.iloc[:, :4]
# Out:
#           date   cpi  policy_rate    neer
# 0   2001-01-31  1.32          1.5   89.24
# 1   2001-02-28  1.44          1.5   90.47
# 2   2001-03-31  1.44         -0.5   89.33
# 3   2001-04-30  2.52         -1.0   87.32
# 4   2001-05-31  2.76          1.5   87.16
# ..         ...   ...          ...     ...
# 278 2024-02-29 -0.77          2.5  118.51
# 279 2024-03-31 -0.47          2.5  118.11
# 280 2024-04-30  0.19          2.5  116.80
# 281 2024-05-31  1.54          2.5  117.21
# 282 2024-06-30  1.54          2.5  117.55
#
# [283 rows x 4 columns]

# %% [markdown]
# ### Filter Row

# %% [markdown]
# #### By Index

# %%
df.loc[:100, :]
# Out:
#           date   cpi  policy_rate   neer  money_supply inflation_target  \
# 0   2001-01-31  1.32         1.50  89.24        147.07          inrange
# 1   2001-02-28  1.44         1.50  90.47        145.49          inrange
# 2   2001-03-31  1.44        -0.50  89.33        140.02          inrange
# 3   2001-04-30  2.52        -1.00  87.32        138.88          inrange
# 4   2001-05-31  2.76         1.50  87.16        139.49          inrange
# ..         ...   ...          ...    ...           ...              ...
# 96  2008-12-31  0.44         2.75  96.45        286.35        outrrange
# 97  2009-01-31 -0.48         2.00  97.22        287.25        outrrange
# 98  2009-02-28 -0.12         1.50  97.97        282.11        outrrange
# 99  2009-03-31 -0.24         1.50  97.62        288.33        outrrange
# 100 2009-04-30 -0.93         1.25  97.14        291.01        outrrange
#
#     type_of_monetary_policy
# 0                      ease
# 1                      ease
# 2                      ease
# 3                      ease
# 4                      ease
# ..                      ...
# 96                    tight
# 97                    tight
# 98                     ease
# 99                     ease
# 100                    ease
#
# [101 rows x 7 columns]

# %%
df.loc[100:, :]
# Out:
#           date   cpi  policy_rate    neer  money_supply inflation_target  \
# 100 2009-04-30 -0.93         1.25   97.14        291.01        outrrange
# 101 2009-05-31 -3.40         1.25   97.07        300.03        outrrange
# 102 2009-06-30 -3.93         1.25   97.50        297.26        outrrange
# 103 2009-07-31 -4.36         1.25   97.32        294.04        outrrange
# 104 2009-08-31 -1.15         1.25   96.89        297.15        outrrange
# ..         ...   ...          ...     ...           ...              ...
# 278 2024-02-29 -0.77         2.50  118.51        718.27        outrrange
# 279 2024-03-31 -0.47         2.50  118.11        711.58        outrrange
# 280 2024-04-30  0.19         2.50  116.80        695.69        outrrange
# 281 2024-05-31  1.54         2.50  117.21        702.68          inrange
# 282 2024-06-30  1.54         2.50  117.55        702.68          inrange
#
#     type_of_monetary_policy
# 100                    ease
# 101                    ease
# 102                    ease
# 103                    ease
# 104                    ease
# ..                      ...
# 278                   tight
# 279                   tight
# 280                   tight
# 281                   tight
# 282                   tight
#
# [183 rows x 7 columns]

# %%
df.loc[10:30, :]
# Out:
#          date     cpi  policy_rate   neer  money_supply inflation_target  \
# 10 2001-11-30     NaN         2.50  89.42        148.71        outrrange
# 11 2001-12-31    0.72         2.25  91.11        148.43        outrrange
# 12 2002-01-31    0.84         2.00  91.88        147.27        outrrange
# 13 2002-02-28    0.36         2.00  92.56        149.90        outrrange
# 14 2002-02-28    0.30         2.00  92.56        149.90        outrrange
# 15 2002-03-31    0.60         2.00  92.89        150.91        outrrange
# 16 2002-04-30    0.47         2.00  92.36        152.66        outrrange
# 17 2002-05-31    0.24         2.00  92.02        155.95        outrrange
# 18 2002-06-30    0.36         2.00  92.03        158.75        outrrange
# 19 2002-07-31    0.24         2.00  92.41        157.59        outrrange
# 20 2002-08-31    0.36         2.00  91.03        159.25        outrrange
# 21 2002-09-30    0.47         2.00  90.00        149.61        outrrange
# 22 2002-10-31    1.53         2.00  88.90        150.47          inrange
# 23 2002-11-30    1.30         1.75  88.67        151.77          inrange
# 24 2002-12-31    1.66         1.75  88.31        154.13          inrange
# 25 2003-01-31    2.24         1.75  88.18        157.04          inrange
# 26 2003-02-28  100.00         1.75  87.85        157.63          inrange
# 27 2003-03-31    1.75         1.75  88.08        157.89          inrange
# 28 2003-04-30    1.52         1.75  87.75        157.73          inrange
# 29 2003-05-31    1.87         1.75  87.30        163.36          inrange
# 30 2003-06-30    1.64         1.25  88.20        161.57          inrange
#
#    type_of_monetary_policy
# 10                   tight
# 11                   tight
# 12                   tight
# 13                   tight
# 14                   tight
# 15                   tight
# 16                   tight
# 17                   tight
# 18                   tight
# 19                   tight
# 20                   tight
# 21                   tight
# 22                   tight
# 23                    ease
# 24                    ease
# 25                    ease
# 26                    ease
# 27                    ease
# 28                    ease
# 29                    ease
# 30                    ease

# %% [markdown]
# #### By Logic

# %%
df[df['type_of_monetary_policy'] == 'ease']
# Out:
#           date   cpi  policy_rate    neer  money_supply inflation_target  \
# 0   2001-01-31  1.32         1.50   89.24        147.07          inrange
# 1   2001-02-28  1.44         1.50   90.47        145.49          inrange
# 2   2001-03-31  1.44        -0.50   89.33        140.02          inrange
# 3   2001-04-30  2.52        -1.00   87.32        138.88          inrange
# 4   2001-05-31  2.76         1.50   87.16        139.49          inrange
# ..         ...   ...          ...     ...           ...              ...
# 264 2022-12-31  5.89         1.25  118.42        721.26        outrrange
# 265 2023-01-31  5.02         1.50  121.91        760.44        outrrange
# 266 2023-02-28  3.79         1.50  119.92        713.86        outrrange
# 267 2023-03-31  2.83         1.75  119.20        739.60          inrange
# 268 2023-04-30  2.67         1.75  119.52        738.30          inrange
#
#     type_of_monetary_policy
# 0                      ease
# 1                      ease
# 2                      ease
# 3                      ease
# 4                      ease
# ..                      ...
# 264                    ease
# 265                    ease
# 266                    ease
# 267                    ease
# 268                    ease
#
# [150 rows x 7 columns]

# %%
df[df['neer'] > 100]
# Out:
#           date   cpi  policy_rate    neer  money_supply inflation_target  \
# 79  2007-07-31  1.73         3.25  101.04        266.82          inrange
# 87  2008-03-31  5.35         3.25  100.51        298.91        outrrange
# 112 2010-04-30  2.97         1.25  100.22        334.93          inrange
# 113 2010-05-31  3.41         1.25  101.54        338.40        outrrange
# 114 2010-06-30  3.32         1.25  101.79        334.56        outrrange
# ..         ...   ...          ...     ...           ...              ...
# 278 2024-02-29 -0.77         2.50  118.51        718.27        outrrange
# 279 2024-03-31 -0.47         2.50  118.11        711.58        outrrange
# 280 2024-04-30  0.19         2.50  116.80        695.69        outrrange
# 281 2024-05-31  1.54         2.50  117.21        702.68          inrange
# 282 2024-06-30  1.54         2.50  117.55        702.68          inrange
#
#     type_of_monetary_policy
# 79                    tight
# 87                    tight
# 112                    ease
# 113                    ease
# 114                    ease
# ..                      ...
# 278                   tight
# 279                   tight
# 280                   tight
# 281                   tight
# 282                   tight
#
# [165 rows x 7 columns]

# %%
df[
    (df['type_of_monetary_policy'] == 'ease') &
    (df['neer'] > 100)
]
# Out:
#           date   cpi  policy_rate    neer  money_supply inflation_target  \
# 112 2010-04-30  2.97         1.25  100.22        334.93          inrange
# 113 2010-05-31  3.41         1.25  101.54        338.40        outrrange
# 114 2010-06-30  3.32         1.25  101.79        334.56        outrrange
# 115 2010-07-31  3.47         1.50  100.37        337.53        outrrange
# 116 2010-08-31  3.36         1.75  101.12        350.76        outrrange
# ..         ...   ...          ...     ...           ...              ...
# 264 2022-12-31  5.89         1.25  118.42        721.26        outrrange
# 265 2023-01-31  5.02         1.50  121.91        760.44        outrrange
# 266 2023-02-28  3.79         1.50  119.92        713.86        outrrange
# 267 2023-03-31  2.83         1.75  119.20        739.60          inrange
# 268 2023-04-30  2.67         1.75  119.52        738.30          inrange
#
#     type_of_monetary_policy
# 112                    ease
# 113                    ease
# 114                    ease
# 115                    ease
# 116                    ease
# ..                      ...
# 264                    ease
# 265                    ease
# 266                    ease
# 267                    ease
# 268                    ease
#
# [106 rows x 7 columns]

# %% [markdown]
# ## Missing Value

# %% [markdown]
# ### Detect

# %%
df.loc[df['cpi'].isnull(), :]
# Out:
#          date  cpi  policy_rate   neer  money_supply inflation_target  \
# 5  2001-06-30  NaN          2.5  88.30        139.53          inrange
# 6  2001-07-31  NaN          2.5  87.81        138.87          inrange
# 7  2001-08-31  NaN          2.5  87.32        144.93          inrange
# 8  2001-09-30  NaN          2.5  88.12        144.44          inrange
# 9  2001-10-31  NaN          2.5  88.26        144.56          inrange
# 10 2001-11-30  NaN          2.5  89.42        148.71        outrrange
#
#    type_of_monetary_policy
# 5                    tight
# 6                    tight
# 7                    tight
# 8                    tight
# 9                    tight
# 10                   tight

# %% [markdown]
# ### Handling

# %%
missing_index = df.loc[df['cpi'].isnull(), :].index
missing_index
# Out:
# Index([5, 6, 7, 8, 9, 10], dtype='int64')

# %% [markdown]
# #### Fill

# %% [markdown]
# ##### Fix Value

# %%
fill_df = df.copy()

# %%
fill_df['cpi'] = fill_df['cpi'].fillna(0)

# %%
fill_df.loc[missing_index, :]
# Out:
#          date  cpi  policy_rate   neer  money_supply inflation_target  \
# 5  2001-06-30  0.0          2.5  88.30        139.53          inrange
# 6  2001-07-31  0.0          2.5  87.81        138.87          inrange
# 7  2001-08-31  0.0          2.5  87.32        144.93          inrange
# 8  2001-09-30  0.0          2.5  88.12        144.44          inrange
# 9  2001-10-31  0.0          2.5  88.26        144.56          inrange
# 10 2001-11-30  0.0          2.5  89.42        148.71        outrrange
#
#    type_of_monetary_policy
# 5                    tight
# 6                    tight
# 7                    tight
# 8                    tight
# 9                    tight
# 10                   tight

# %% [markdown]
# ##### Fill Foward Value

# %%
ffill_df = df.copy()

# %%
ffill_df.loc[4, :]
# Out:
# date                       2001-05-31 00:00:00
# cpi                                       2.76
# policy_rate                                1.5
# neer                                     87.16
# money_supply                            139.49
# inflation_target                       inrange
# type_of_monetary_policy                   ease
# Name: 4, dtype: object

# %%
ffill_df['cpi'] = ffill_df['cpi'].ffill()

# %%
ffill_df.loc[missing_index, :]
# Out:
#          date   cpi  policy_rate   neer  money_supply inflation_target  \
# 5  2001-06-30  2.76          2.5  88.30        139.53          inrange
# 6  2001-07-31  2.76          2.5  87.81        138.87          inrange
# 7  2001-08-31  2.76          2.5  87.32        144.93          inrange
# 8  2001-09-30  2.76          2.5  88.12        144.44          inrange
# 9  2001-10-31  2.76          2.5  88.26        144.56          inrange
# 10 2001-11-30  2.76          2.5  89.42        148.71        outrrange
#
#    type_of_monetary_policy
# 5                    tight
# 6                    tight
# 7                    tight
# 8                    tight
# 9                    tight
# 10                   tight

# %% [markdown]
# ##### Fill Backward Value

# %%
bfill_df = df.copy()

# %%
ffill_df.loc[11, :]
# Out:
# date                       2001-12-31 00:00:00
# cpi                                       0.72
# policy_rate                               2.25
# neer                                     91.11
# money_supply                            148.43
# inflation_target                     outrrange
# type_of_monetary_policy                  tight
# Name: 11, dtype: object

# %%
bfill_df['cpi'] = bfill_df['cpi'].bfill()

# %%
bfill_df.loc[missing_index, :]
# Out:
#          date   cpi  policy_rate   neer  money_supply inflation_target  \
# 5  2001-06-30  0.72          2.5  88.30        139.53          inrange
# 6  2001-07-31  0.72          2.5  87.81        138.87          inrange
# 7  2001-08-31  0.72          2.5  87.32        144.93          inrange
# 8  2001-09-30  0.72          2.5  88.12        144.44          inrange
# 9  2001-10-31  0.72          2.5  88.26        144.56          inrange
# 10 2001-11-30  0.72          2.5  89.42        148.71        outrrange
#
#    type_of_monetary_policy
# 5                    tight
# 6                    tight
# 7                    tight
# 8                    tight
# 9                    tight
# 10                   tight

# %% [markdown]
# ##### Imputation

# %%
imputation_df = df.copy()

# %%
imputation_df['cpi'].mean()
# Out:
# 2.345198555956679

# %%
imputation_df['cpi'] = imputation_df['cpi'].fillna(imputation_df['cpi'].mean())

# %%
imputation_df.loc[missing_index, :]
# Out:
#          date       cpi  policy_rate   neer  money_supply inflation_target  \
# 5  2001-06-30  2.345199          2.5  88.30        139.53          inrange
# 6  2001-07-31  2.345199          2.5  87.81        138.87          inrange
# 7  2001-08-31  2.345199          2.5  87.32        144.93          inrange
# 8  2001-09-30  2.345199          2.5  88.12        144.44          inrange
# 9  2001-10-31  2.345199          2.5  88.26        144.56          inrange
# 10 2001-11-30  2.345199          2.5  89.42        148.71        outrrange
#
#    type_of_monetary_policy
# 5                    tight
# 6                    tight
# 7                    tight
# 8                    tight
# 9                    tight
# 10                   tight

# %% [markdown]
# ##### Interpolatation

# %%
interpolation_df = df.copy()

# %%
interpolation_df.loc[4:11]
# Out:
#          date   cpi  policy_rate   neer  money_supply inflation_target  \
# 4  2001-05-31  2.76         1.50  87.16        139.49          inrange
# 5  2001-06-30   NaN         2.50  88.30        139.53          inrange
# 6  2001-07-31   NaN         2.50  87.81        138.87          inrange
# 7  2001-08-31   NaN         2.50  87.32        144.93          inrange
# 8  2001-09-30   NaN         2.50  88.12        144.44          inrange
# 9  2001-10-31   NaN         2.50  88.26        144.56          inrange
# 10 2001-11-30   NaN         2.50  89.42        148.71        outrrange
# 11 2001-12-31  0.72         2.25  91.11        148.43        outrrange
#
#    type_of_monetary_policy
# 4                     ease
# 5                    tight
# 6                    tight
# 7                    tight
# 8                    tight
# 9                    tight
# 10                   tight
# 11                   tight

# %%
interpolation_df['cpi'] = interpolation_df['cpi'].interpolate(method='linear')

# %%
interpolation_df.loc[4:11]
# Out:
#          date       cpi  policy_rate   neer  money_supply inflation_target  \
# 4  2001-05-31  2.760000         1.50  87.16        139.49          inrange
# 5  2001-06-30  2.468571         2.50  88.30        139.53          inrange
# 6  2001-07-31  2.177143         2.50  87.81        138.87          inrange
# 7  2001-08-31  1.885714         2.50  87.32        144.93          inrange
# 8  2001-09-30  1.594286         2.50  88.12        144.44          inrange
# 9  2001-10-31  1.302857         2.50  88.26        144.56          inrange
# 10 2001-11-30  1.011429         2.50  89.42        148.71        outrrange
# 11 2001-12-31  0.720000         2.25  91.11        148.43        outrrange
#
#    type_of_monetary_policy
# 4                     ease
# 5                    tight
# 6                    tight
# 7                    tight
# 8                    tight
# 9                    tight
# 10                   tight
# 11                   tight

# %% [markdown]
# #### Remove

# %%
remove_df = df.copy()

# %%
remove_df.loc[4:11]
# Out:
#          date   cpi  policy_rate   neer  money_supply inflation_target  \
# 4  2001-05-31  2.76         1.50  87.16        139.49          inrange
# 5  2001-06-30   NaN         2.50  88.30        139.53          inrange
# 6  2001-07-31   NaN         2.50  87.81        138.87          inrange
# 7  2001-08-31   NaN         2.50  87.32        144.93          inrange
# 8  2001-09-30   NaN         2.50  88.12        144.44          inrange
# 9  2001-10-31   NaN         2.50  88.26        144.56          inrange
# 10 2001-11-30   NaN         2.50  89.42        148.71        outrrange
# 11 2001-12-31  0.72         2.25  91.11        148.43        outrrange
#
#    type_of_monetary_policy
# 4                     ease
# 5                    tight
# 6                    tight
# 7                    tight
# 8                    tight
# 9                    tight
# 10                   tight
# 11                   tight

# %%
remove_df = remove_df.dropna()

# %%
remove_df.loc[4:11]
# Out:
#          date   cpi  policy_rate   neer  money_supply inflation_target  \
# 4  2001-05-31  2.76         1.50  87.16        139.49          inrange
# 11 2001-12-31  0.72         2.25  91.11        148.43        outrrange
#
#    type_of_monetary_policy
# 4                     ease
# 11                   tight

# %%
remove_df = remove_df.reset_index(drop=True)

# %%
remove_df.loc[4:11]
# Out:
#          date   cpi  policy_rate   neer  money_supply inflation_target  \
# 4  2001-05-31  2.76         1.50  87.16        139.49          inrange
# 5  2001-12-31  0.72         2.25  91.11        148.43        outrrange
# 6  2002-01-31  0.84         2.00  91.88        147.27        outrrange
# 7  2002-02-28  0.36         2.00  92.56        149.90        outrrange
# 8  2002-02-28  0.30         2.00  92.56        149.90        outrrange
# 9  2002-03-31  0.60         2.00  92.89        150.91        outrrange
# 10 2002-04-30  0.47         2.00  92.36        152.66        outrrange
# 11 2002-05-31  0.24         2.00  92.02        155.95        outrrange
#
#    type_of_monetary_policy
# 4                     ease
# 5                    tight
# 6                    tight
# 7                    tight
# 8                    tight
# 9                    tight
# 10                   tight
# 11                   tight

# %% [markdown]
# ## Duplicate Data

# %% [markdown]
# ### Detect

# %%
df.loc[df.duplicated(subset=['date']), :]
# Out:
#          date  cpi  policy_rate   neer  money_supply inflation_target  \
# 14 2002-02-28  0.3          2.0  92.56         149.9        outrrange
#
#    type_of_monetary_policy
# 14                   tight

# %%
df.loc[df.duplicated(subset=['date'], keep=False), :]
# Out:
#          date   cpi  policy_rate   neer  money_supply inflation_target  \
# 13 2002-02-28  0.36          2.0  92.56         149.9        outrrange
# 14 2002-02-28  0.30          2.0  92.56         149.9        outrrange
#
#    type_of_monetary_policy
# 13                   tight
# 14                   tight

# %% [markdown]
# ### Handling

# %% [markdown]
# #### Keep First

# %%
keep_first_df = df.copy()

# %%
keep_first_df.loc[12:15]
# Out:
#          date   cpi  policy_rate   neer  money_supply inflation_target  \
# 12 2002-01-31  0.84          2.0  91.88        147.27        outrrange
# 13 2002-02-28  0.36          2.0  92.56        149.90        outrrange
# 14 2002-02-28  0.30          2.0  92.56        149.90        outrrange
# 15 2002-03-31  0.60          2.0  92.89        150.91        outrrange
#
#    type_of_monetary_policy
# 12                   tight
# 13                   tight
# 14                   tight
# 15                   tight

# %%
keep_first_df = keep_first_df.drop_duplicates(subset=['date'], keep='first').reset_index(drop=True)

# %%
keep_first_df.loc[12:15]
# Out:
#          date   cpi  policy_rate   neer  money_supply inflation_target  \
# 12 2002-01-31  0.84          2.0  91.88        147.27        outrrange
# 13 2002-02-28  0.36          2.0  92.56        149.90        outrrange
# 14 2002-03-31  0.60          2.0  92.89        150.91        outrrange
# 15 2002-04-30  0.47          2.0  92.36        152.66        outrrange
#
#    type_of_monetary_policy
# 12                   tight
# 13                   tight
# 14                   tight
# 15                   tight

# %% [markdown]
# #### Keep Last

# %%
keep_last_df = df.copy()

# %%
keep_last_df.loc[12:15]
# Out:
#          date   cpi  policy_rate   neer  money_supply inflation_target  \
# 12 2002-01-31  0.84          2.0  91.88        147.27        outrrange
# 13 2002-02-28  0.36          2.0  92.56        149.90        outrrange
# 14 2002-02-28  0.30          2.0  92.56        149.90        outrrange
# 15 2002-03-31  0.60          2.0  92.89        150.91        outrrange
#
#    type_of_monetary_policy
# 12                   tight
# 13                   tight
# 14                   tight
# 15                   tight

# %%
keep_last_df = keep_last_df.drop_duplicates(subset=['date'], keep='last').reset_index(drop=True)

# %%
keep_last_df.loc[12:15]
# Out:
#          date   cpi  policy_rate   neer  money_supply inflation_target  \
# 12 2002-01-31  0.84          2.0  91.88        147.27        outrrange
# 13 2002-02-28  0.30          2.0  92.56        149.90        outrrange
# 14 2002-03-31  0.60          2.0  92.89        150.91        outrrange
# 15 2002-04-30  0.47          2.0  92.36        152.66        outrrange
#
#    type_of_monetary_policy
# 12                   tight
# 13                   tight
# 14                   tight
# 15                   tight
